# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Enter_Your_Roboflow_API_Key_Here") # www.roboflow.com/signup for free API key
project = rf.workspace("ucp-xi9nf").project("pakistani-currency-note-data")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to pakistani-currency-note-data-2 in yolov11:: 100%|██████████| 19224/19224 [00:06<00:00, 2989.75it/s]

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 905.3/905.3 kB 44.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# Train the model
train_results = model.train(
    data="/content/pakistani-currency-note-data-2/data.yaml",  # path to dataset YAML
    epochs=60,  # number of training epochs
    imgsz=640,  # training image size
    device="0",  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
)

# Evaluate model performance on the validation set
metrics = model.val()
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 277MB/s]
# Ultralytics 8.3.57 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# # Evaluate model performance on the validation set
metrics = model.val()
# Out:
# Ultralytics 8.3.57 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/pakistani-currency-note-data-2/valid/labels.cache... 802 images, 0 backgrounds, 0 corrupt: 100%|██████████| 802/802 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 51/51 [00:12<00:00,  3.94it/s]
#                    all        802       3898      0.898      0.869      0.902      0.489
#                     10        108        544      0.961      0.906      0.973      0.562
#                    100         90        327       0.81      0.718       0.79      0.297
#                   1000        103        519      0.947      0.967      0.983      0.643
#                     20         97        506       0.95      0.957      0.978      0.616
#                     50         92        459       0.86      0.898      0.885      0.545
# ...

# %%
# Perform object detection on an image
results = model("/content/IMG20211228001352.jpg")
results[0].show()

# Export the model to ONNX format # return path to exported model
# Out:
# image 1/1 /content/IMG20211228001352.jpg: 480x640 7 50s, 48.7ms
# Speed: 3.3ms preprocess, 48.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=832x624>

# %%
results = model("/content/IMG20211228122602.jpg")
results[0].show()
# Out:
# image 1/1 /content/IMG20211228122602.jpg: 480x640 7 500s, 13.7ms
# Speed: 2.6ms preprocess, 13.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=832x624>

# %%
path = model.export(format="onnx")
print(path)
# Out:
# Ultralytics 8.3.57 🚀 Python-3.10.12 torch-2.5.1+cu121 CPU (Intel Xeon 2.00GHz)
#
# PyTorch: starting from 'runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 12, 8400) (5.2 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxslim', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 231.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.6/142.6 kB 183.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.5/291.5 MB 146.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 147.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 162.6 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 21.5s, installed 3 packages: ['onnx>=1.12.0', 'onnxslim', 'onnxruntime-gpu']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ...

# %%
from ultralytics import YOLO
model = YOLO("best.onnx")
# Perform object detection on an image
result = model("test/Real-Notes (230).jpg")
result[0].show()
# Out:
# WARNING Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Loading YOLOv11/best.onnx for ONNX Runtime inference...
# Using ONNX Runtime 1.23.2 CPUExecutionProvider
#
# image 1/1 d:\BS Computer Science\FYP-Currency Detection\FYP-Currency Detection\YOLOv11\test\Real-Notes (230).jpg: 640x640 7 1000s, 676.4ms
# Speed: 14.1ms preprocess, 676.4ms inference, 23.5ms postprocess per image at shape (1, 3, 640, 640)
